# %%
import os
import requests
from pprint import pprint
import pandas as pd

# %%
# # Lista de IDs dos eventos
# ids = [12117117, 12117120, 12117115, 12117121, 12117123, 12117114, 12117122, 12117119, 12117116, 12117118]

# %%
# url = "https://www.sofascore.com/api/v1/unique-tournament/325/season/58766/events/last/0"
# response = requests.get(url)
# data = response.json()
# pprint(data)

# %%
import requests
import json

url_base = "https://www.sofascore.com/api/v1/unique-tournament/325/season/58766/events/last/"
page_number = 0
all_events = []

while True:
  url = url_base + str(page_number)
  response = requests.get(url)

  if response.status_code == 404:
    break

  if response.status_code == 200:
    data = json.loads(response.content)

    if 'events' in data:
        all_events.extend(data['events'])
    else:
        print(f"Aviso: Chave 'events' não encontrada na página {page_number}.")

    page_number += 1
  else:
    print(f"Erro na requisição da página {page_number}: Código de status {response.status_code}")
    break

print(f"Total de eventos coletados: {len(all_events)}")
# Out:
# Total de eventos coletados: 295

# %%
pprint(all_events[0]['id'])
# Out:
# 12117241

# %%
qtd_eventos = len(all_events)
print(qtd_eventos)
# Out:
# 295

# %%
# Função para fazer requisição e obter dados de um evento
def get_event_data(event_id):
    url = f"https://www.sofascore.com/api/v1/event/{event_id}"
    response = requests.get(url)
    return response.json()

# %%
# Função para fazer requisição e obter lineups de um evento
def get_event_lineups(event_id):
    url = f"https://www.sofascore.com/api/v1/event/{event_id}/lineups"
    response = requests.get(url)
    return response.json()

# %%
# Função para gerar o conteúdo do documento para um jogador
def generate_player_document(team, player):
    player_name = player['player']['name']
    position_map = {
        'G': 'goalkeeper',
        'D': 'defender',
        'M': 'midfield',
        'F': 'forward'
    }
    position = position_map.get(player['position'], 'Unknown')

    document_content = f"Team: {team} | Player: {player_name} | Position: {position}"

    # Estatísticas de acordo com a posição do jogador
    if position == 'forward':
        statistics_keys = ['goals', 'goalAssist', 'onTargetScoringAttempt']
    elif position == 'midfield':
        statistics_keys = ['accuratePass', 'keyPass', 'goalAssist']
    elif position == 'defender':
        statistics_keys = ['totalTackle', 'totalClearance', 'interceptionWon']
    elif position == 'goalkeeper':
        statistics_keys = ['saves', 'goalsPrevented', 'goodHighClaim']
    else:
        statistics_keys = []

    # Adiciona as estatísticas
    for key in statistics_keys:
        value = player['statistics'].get(key, 'N/A')
        if value != 'N/A':
            document_content += f" | {key}: {value}"

    # Adiciona rating se existir
    rating = player['statistics'].get('rating', 'N/A')
    if rating != 'N/A':
        document_content += f" | rating: {rating}"

    return document_content

# %%
# pprint(get_event_lineups(12117200))

# %%
# Função para salvar documento em arquivo .txt
def save_match_document(filename, content, is_first):
    # Cria a pasta 'data' se não existir
    os.makedirs('data', exist_ok=True)

    # Define o caminho completo do arquivo dentro da pasta 'data'
    filepath = os.path.join('data', filename)

    # Define o modo de escrita ('w' para o primeiro documento, 'a' para os subsequentes)
    mode = 'w' if is_first else 'a'
    with open(filepath, mode) as file:
        file.write(content + "\n")

# %%
from collections import defaultdict

# Mapeamento de posições conforme a função generate_player_document
position_map = {
    'G': 'goalkeeper',
    'D': 'defender',
    'M': 'midfield',
    'F': 'forward'
}

# Função para extrair todas as chaves de 'statistics' por posição
def extract_statistics_by_position(players):
    statistics_by_position = defaultdict(set)  # Cria um dicionário com conjuntos para cada posição

    for player in players:
        # Obtém a posição usando o mapeamento fornecido
        raw_position = player.get('position')
        position = position_map.get(raw_position, 'Unknown')

        if 'statistics' in player:
            statistics_by_position[position].update(player['statistics'].keys())

    return statistics_by_position

# Função principal para processar eventos e coletar estatísticas por posição
def process_events(qtd_eventos, all_events):
    all_statistics_by_position = defaultdict(set)  # Dicionário global para todas as posições

    for event in range(qtd_eventos):
        # Obter dados do evento
        event_id = all_events[event]['id']
        data_games = get_event_data(event_id)

        home_team = data_games['event']['homeTeam']['name']
        away_team = data_games['event']['awayTeam']['name']
        round = data_games['event']['roundInfo']['round']
        status = data_games['event']['status']['description']
        print(f"{home_team} x {away_team} - rodada {round} - id {event_id} - status {status}")

        if status == 'Ended':
            home_score = data_games['event']['homeScore']['current']
            away_score = data_games['event']['awayScore']['current']
            round_number = data_games['event']['roundInfo']['round']

            # Define o nome do arquivo com base nos times
            match_title = f"Rodada{round_number}_{home_team}_vs_{away_team}.txt"

            # Escrever estatísticas básicas da partida
            match_summary = f"Match: {home_team} vs {away_team} | Round: {round} | Status: {status} | Score: {home_team} {home_score} - {away_score} {away_team}"
            save_match_document(match_title, match_summary, is_first=True)

            # Obter lineups do evento
            lineups = get_event_lineups(event_id)

            # Processar jogadores do time da casa
            home_players = lineups['home']['players']
            home_statistics_by_position = extract_statistics_by_position(home_players)

            for position, statistics in home_statistics_by_position.items():
                all_statistics_by_position[position].update(statistics)

            for player in home_players:
                player_document = generate_player_document(home_team, player)
                save_match_document(match_title, player_document, is_first=False)

            # Processar jogadores do time visitante
            away_players = lineups['away']['players']
            away_statistics_by_position = extract_statistics_by_position(away_players)

            for position, statistics in away_statistics_by_position.items():
                all_statistics_by_position[position].update(statistics)

            for player in away_players:
                player_document = generate_player_document(away_team, player)
                save_match_document(match_title, player_document, is_first=False)

    return all_statistics_by_position

# Executa o processamento dos eventos
qtd_eventos = len(all_events)  # Supondo que você tenha o total de eventos
all_statistics_by_position = process_events(qtd_eventos, all_events)

# Exibe todas as chaves de 'statistics' por posição
print("Chaves de 'statistics' encontradas por posição:")
for position, statistics in all_statistics_by_position.items():
    print(f"Posição {position}: {statistics}")
# Out:
# Fortaleza x Bahia - rodada 27 - id 12117241 - status Ended
# Atlético Mineiro x Red Bull Bragantino - rodada 27 - id 12117235 - status Ended
# Vasco x Palmeiras - rodada 27 - id 12117238 - status Ended
# Cuiabá x Cruzeiro - rodada 27 - id 12117242 - status Ended
# São Paulo x Internacional - rodada 27 - id 12117240 - status Ended
# Grêmio x Flamengo - rodada 27 - id 12117234 - status Ended
# Criciúma x Athletico - rodada 27 - id 12117243 - status Ended
# Red Bull Bragantino x Internacional - rodada 16 - id 12851651 - status Ended
# Grêmio x Criciúma - rodada 5 - id 12860733 - status Ended
# Palmeiras x Atlético Mineiro - rodada 28 - id 12117249 - status Ended
# Botafogo x Grêmio - rodada 28 - id 12117248 - status Ended
# Juventude x Red Bull Bragantino - rodada 28 - id 12117253 - status Ended
# Fortaleza x Cuiabá - rodada 28 - id 12117251 - status Ended
# Atlético Goianiense x Fluminense - rodada 28 - id 12117252 - status Ended
# São Paulo x Corinthians - rodada 28 - id 12117250 - status Ended
# Bahia x Criciúma - rodada 28 - id 12117246 - status Ended
# Internacional x Vitória - rodada 28 - id 12117244 - status Ended
# Cruzeiro x Vasco - rodada 28 - id 12117245 - status Ended
# Flamengo x Athletico - rodada 28 - id 12117247 - status Ended
# Criciúma x Atlético Goianiense - rodada 29 - id 12117263 - status Ended
# Fluminense x Cruzeiro - rodada 29 - id 12117257 - status Ended
# Grêmio x Fortaleza - rodada 29 - id 12117254 - status Ended
# Atlético Mineiro x Vitória - rodada 29 - id 12117255 - status Ended
# Athletico x Botafogo - rodada 29 - id 12117261 - status Ended
# Red Bull Bragantino x Palmeiras - rodada 29 - id 12117260 - status Ended
# Cuiabá x São Paulo - rodada 29 - id 12117262 - status Ended
# Corinthians x Internacional - rodada 29 - id 12117259 - status Ended
# Bahia x Flamengo - rodada 29 - id 12117256 - status Ended
# Vasco x Juventude - rodada 29 - id 12117258 - status Ended
# Atlético Mineiro x Grêmio - rodada 6 - id 12943807 - status Ended
# Internacional x Cruzeiro - rodada 24 - id 12117204 - status Ended
# Flamengo x Red Bull Bragantino - rodada 24 - id 12117207 - status Ended
# Vasco x Athletico - rodada 24 - id 12117208 - status Ended
# Criciúma x Red Bull Bragantino - rodada 19 - id 12727203 - status Ended
# Cruzeiro x Internacional - rodada 5 - id 12629260 - status Ended
# Cuiabá x Criciúma - rodada 25 - id 12117222 - status Ended
# Botafogo x Fortaleza - rodada 25 - id 12117218 - status Ended
# Cruzeiro x Atlético Goianiense - rodada 25 - id 12117215 - status Ended
# Grêmio x Atlético Mineiro - rodada 25 - id 12117214 - status Ended
# Corinthians x Flamengo - rodada 25 - id 12117219 - status Ended
# Juventude x Internacional - rodada 25 - id 12117223 - status Ended
# Red Bull Bragantino x Bahia - rodada 25 - id 12117220 - status Ended
# Vitória x Vasco - rodada 25 - id 12117216 - status Ended
# Fluminense x São Paulo - rodada 25 - id 12117217 - status Ended
# Athletico x Palmeiras - rodada 25 - id 12117221 - status Ended
# Cuiabá x Juventude - rodada 16 - id 12731927 - status Ended
# Internacional x Fortaleza - rodada 19 - id 12785268 - status Ended
# Atlético Goianiense x Vitória - rodada 26 - id 12117232 - status Ended
# Athletico x Fortaleza - rodada 26 - id 12117231 - status Ended
# Botafogo x Corinthians - rodada 26 - id 12117228 - status Ended
# Red Bull Bragantino x Grêmio - rodada 26 - id 12117230 - status Ended
# Juventude x Fluminense - rodada 26 - id 12117233 - status Ended
# Palmeiras x Criciúma - rodada 26 - id 12117229 - status Ended
# Bahia x Atlético Mineiro - rodada 26 - id 12117226 - status Ended
# Cruzeiro x São Paulo - rodada 26 - id 12117225 - status Ended
# Flamengo x Vasco - rodada 26 - id 12117227 - status Ended
# Internacional x Cuiabá - rodada 26 - id 12117224 - status Ended
# Vitória x Juventude - rodada 27 - id 12117236 - status Ended
# Corinthians x Atlético Goianiense - rodada 27 - id 12117239 - status Ended
# Fluminense x Botafogo - rodada 27 - id 12117237 - status Ended
# Internacional x Palmeiras - rodada 21 - id 12117174 - status Ended
# Cruzeiro x Fortaleza - rodada 21 - id 12117175 - status Ended
# Fortaleza x Criciúma - rodada 22 - id 12117191 - status Ended
# Cuiabá x Grêmio - rodada 22 - id 12117192 - status Ended
# Cruzeiro x Atlético Mineiro - rodada 22 - id 12117185 - status Ended
# Vasco x Fluminense - rodada 22 - id 12117188 - status Ended
# Corinthians x Red Bull Bragantino - rodada 22 - id 12117189 - status Ended
# Juventude x Botafogo - rodada 22 - id 12117193 - status Ended
# Bahia x Vitória - rodada 22 - id 12117186 - status Ended
# São Paulo x Atlético Goianiense - rodada 22 - id 12117190 - status Ended
# Flamengo x Palmeiras - rodada 22 - id 12117187 - status Ended
# Internacional x Athletico - rodada 22 - id 12117184 - status Ended
# Internacional x Juventude - rodada 6 - id 12629257 - status Ended
# Atlético Mineiro x Cuiabá - rodada 23 - id 12117195 - status Ended
# Grêmio x Bahia - rodada 23 - id 12117194 - status Ended
# Red Bull Bragantino x Fortaleza - rodada 23 - id 12117200 - status Ended
# Fluminense x Corinthians - rodada 23 - id 12117197 - status Ended
# Atlético Goianiense x Internacional - rodada 23 - id 12117202 - status Ended
# Criciúma x Vasco - rodada 23 - id 12117203 - status Ended
# Palmeiras x São Paulo - rodada 23 - id 12117199 - status Ended
# Athletico x Juventude - rodada 23 - id 12117201 - status Ended
# Botafogo x Flamengo - rodada 23 - id 12117198 - status Ended
# Vitória x Cruzeiro - rodada 23 - id 12117196 - status Ended
# Atlético Goianiense x Juventude - rodada 24 - id 12117212 - status Ended
# Palmeiras x Cuiabá - rodada 24 - id 12117209 - status Ended
# Atlético Mineiro x Fluminense - rodada 24 - id 12117205 - status Ended
# Criciúma x Grêmio - rodada 24 - id 12117213 - status Ended
# Bahia x Botafogo - rodada 24 - id 12117206 - status Ended
# Fortaleza x Corinthians - rodada 24 - id 12117211 - status Ended
# São Paulo x Vitória - rodada 24 - id 12117210 - status Ended
# Cuiabá x Fluminense - rodada 18 - id 12117152 - status Ended
# Criciúma x Red Bull Bragantino - rodada 19 - id 12117163 - status Postponed
# Internacional x Fortaleza - rodada 19 - id 12117154 - status Postponed
# Vasco x Cuiabá - rodada 19 - id 12117158 - status Postponed
# Athletico x Atlético Mineiro - rodada 19 - id 12117161 - status Postponed
# Criciúma x Fortaleza - rodada 3 - id 12479063 - status Ended
# Cruzeiro x Juventude - rodada 19 - id 12117155 - status Ended
# São Paulo x Botafogo - rodada 19 - id 12117160 - status Ended
# Vitória x Flamengo - rodada 19 - id 12117156 - status Ended
# Atlético Goianiense x Bahia - rodada 19 - id 12117162 - status Ended
# Fluminense x Palmeiras - rodada 19 - id 12117157 - status Ended
# Corinthians x Grêmio - rodada 19 - id 12117159 - status Ended
# Juventude x Criciúma - rodada 20 - id 12117173 - status Ended
# Palmeiras x Vitória - rodada 20 - id 12117169 - status Ended
# Bahia x Internacional - rodada 20 - id 12117166 - status Ended
# Botafogo x Cruzeiro - rodada 20 - id 12117168 - status Ended
# Fortaleza x São Paulo - rodada 20 - id 12117171 - status Ended
# Red Bull Bragantino x Fluminense - rodada 20 - id 12117170 - status Ended
# Flamengo x Atlético Goianiense - rodada 20 - id 12117167 - status Ended
# Cuiabá x Athletico - rodada 20 - id 12117172 - status Ended
# Grêmio x Vasco - rodada 20 - id 12117164 - status Ended
# Atlético Mineiro x Corinthians - rodada 20 - id 12117165 - status Ended
# Vitória x Cuiabá - rodada 21 - id 12117176 - status Ended
# Vasco x Red Bull Bragantino - rodada 21 - id 12117178 - status Ended
# Atlético Goianiense x Botafogo - rodada 21 - id 12117182 - status Ended
# Criciúma x Atlético Mineiro - rodada 21 - id 12117183 - status Ended
# São Paulo x Flamengo - rodada 21 - id 12117180 - status Ended
# Athletico x Grêmio - rodada 21 - id 12117181 - status Ended
# Fluminense x Bahia - rodada 21 - id 12117177 - status Ended
# Corinthians x Juventude - rodada 21 - id 12117179 - status Ended
# Botafogo x Atlético Mineiro - rodada 15 - id 12117118 - status Ended
# Red Bull Bragantino x Internacional - rodada 16 - id 12117130 - status Postponed
# Grêmio x Cruzeiro - rodada 16 - id 12117124 - status Ended
# Cuiabá x Juventude - rodada 16 - id 12117132 - status Postponed
# Athletico x Bahia - rodada 16 - id 12117131 - status Ended
# Vasco x Corinthians - rodada 16 - id 12117128 - status Ended
# Palmeiras x Atlético Goianiense - rodada 16 - id 12117129 - status Ended
# Criciúma x Fluminense - rodada 16 - id 12117133 - status Ended
# Flamengo x Fortaleza - rodada 16 - id 12117127 - status Ended
# Vitória x Botafogo - rodada 16 - id 12117126 - status Ended
# Atlético Mineiro x São Paulo - rodada 16 - id 12117125 - status Ended
# Bahia x Cuiabá - rodada 17 - id 12117136 - status Ended
# Cruzeiro x Red Bull Bragantino - rodada 17 - id 12117135 - status Ended
# Juventude x Atlético Mineiro - rodada 17 - id 12117143 - status Ended
# Corinthians x Criciúma - rodada 17 - id 12117139 - status Ended
# Fluminense x Athletico - rodada 17 - id 12117137 - status Postponed
# Internacional x Flamengo - rodada 17 - id 12117134 - status Postponed
# Atlético Goianiense x Vasco - rodada 17 - id 12117142 - status Ended
# São Paulo x Grêmio - rodada 17 - id 12117140 - status Ended
# Fortaleza x Vitória - rodada 17 - id 12117141 - status Ended
# Botafogo x Palmeiras - rodada 17 - id 12117138 - status Ended
# Flamengo x Criciúma - rodada 18 - id 12117147 - status Ended
# Botafogo x Internacional - rodada 18 - id 12117148 - status Ended
# Palmeiras x Cruzeiro - rodada 18 - id 12117149 - status Ended
# Grêmio x Vitória - rodada 18 - id 12117144 - status Ended
# Atlético Mineiro x Vasco - rodada 18 - id 12117145 - status Ended
# Bahia x Corinthians - rodada 18 - id 12117146 - status Ended
# Fortaleza x Atlético Goianiense - rodada 18 - id 12117151 - status Ended
# Red Bull Bragantino x Athletico - rodada 18 - id 12117150 - status Ended
# Juventude x São Paulo - rodada 18 - id 12117153 - status Ended
# São Paulo x Criciúma - rodada 12 - id 12117090 - status Ended
# Cuiabá x Red Bull Bragantino - rodada 13 - id 12117102 - status Ended
# Vasco x Botafogo - rodada 13 - id 12117098 - status Ended
# Atlético Mineiro x Atlético Goianiense - rodada 13 - id 12117095 - status Ended
# Fortaleza x Juventude - rodada 13 - id 12117101 - status Ended
# Grêmio x Fluminense - rodada 13 - id 12117094 - status Ended
# São Paulo x Bahia - rodada 13 - id 12117100 - status Ended
# Vitória x Athletico - rodada 13 - id 12117096 - status Ended
# Criciúma x Internacional - rodada 13 - id 12117103 - status Ended
# Flamengo x Cruzeiro - rodada 13 - id 12117097 - status Ended
# Palmeiras x Corinthians - rodada 13 - id 12117099 - status Ended
# Cuiabá x Botafogo - rodada 14 - id 12117112 - status Ended
# Criciúma x Cruzeiro - rodada 14 - id 12117113 - status Ended
# Vasco x Fortaleza - rodada 14 - id 12117108 - status Ended
# Red Bull Bragantino x Atlético Goianiense - rodada 14 - id 12117110 - status Ended
# Athletico x São Paulo - rodada 14 - id 12117111 - status Ended
# Atlético Mineiro x Flamengo - rodada 14 - id 12117105 - status Ended
# Bahia x Juventude - rodada 14 - id 12117106 - status Ended
# Grêmio x Palmeiras - rodada 14 - id 12117104 - status Ended
# Fluminense x Internacional - rodada 14 - id 12117107 - status Ended
# Corinthians x Vitória - rodada 14 - id 12117109 - status Ended
# São Paulo x Red Bull Bragantino - rodada 15 - id 12117120 - status Ended
# Flamengo x Cuiabá - rodada 15 - id 12117117 - status Ended
# Juventude x Grêmio - rodada 15 - id 12117123 - status Ended
# Fortaleza x Fluminense - rodada 15 - id 12117121 - status Ended
# Cruzeiro x Corinthians - rodada 15 - id 12117115 - status Ended
# Internacional x Vasco - rodada 15 - id 12117114 - status Ended
# Vitória x Criciúma - rodada 15 - id 12117116 - status Ended
# Atlético Goianiense x Athletico - rodada 15 - id 12117122 - status Ended
# Palmeiras x Bahia - rodada 15 - id 12117119 - status Ended
# Atlético Mineiro x Palmeiras - rodada 9 - id 12117055 - status Ended
# Atlético Goianiense x Criciúma - rodada 10 - id 12117072 - status Ended
# Botafogo x Athletico - rodada 10 - id 12117068 - status Ended
# Juventude x Vasco - rodada 10 - id 12117073 - status Ended
# Fortaleza x Grêmio - rodada 10 - id 12117071 - status Ended
# São Paulo x Cuiabá - rodada 10 - id 12117070 - status Ended
# Cruzeiro x Fluminense - rodada 10 - id 12117065 - status Ended
# Internacional x Corinthians - rodada 10 - id 12117064 - status Ended
# Vitória x Atlético Mineiro - rodada 10 - id 12117066 - status Ended
# Flamengo x Bahia - rodada 10 - id 12117067 - status Ended
# Palmeiras x Red Bull Bragantino - rodada 10 - id 12117069 - status Ended
# Criciúma x Botafogo - rodada 11 - id 12117083 - status Ended
# Grêmio x Internacional - rodada 11 - id 12117074 - status Ended
# Cuiabá x Atlético Goianiense - rodada 11 - id 12117082 - status Ended
# Vasco x São Paulo - rodada 11 - id 12117078 - status Ended
# Bahia x Cruzeiro - rodada 11 - id 12117076 - status Ended
# Athletico x Corinthians - rodada 11 - id 12117081 - status Ended
# Fluminense x Flamengo - rodada 11 - id 12117077 - status Ended
# Red Bull Bragantino x Vitória - rodada 11 - id 12117080 - status Ended
# Atlético Mineiro x Fortaleza - rodada 11 - id 12117075 - status Ended
# Palmeiras x Juventude - rodada 11 - id 12117079 - status Ended
# Cruzeiro x Athletico - rodada 12 - id 12117085 - status Ended
# Botafogo x Red Bull Bragantino - rodada 12 - id 12117088 - status Ended
# Atlético Goianiense x Grêmio - rodada 12 - id 12117092 - status Ended
# Corinthians x Cuiabá - rodada 12 - id 12117089 - status Ended
# Juventude x Flamengo - rodada 12 - id 12117093 - status Ended
# Internacional x Atlético Mineiro - rodada 12 - id 12117084 - status Ended
# Bahia x Vasco - rodada 12 - id 12117086 - status Ended
# Fortaleza x Palmeiras - rodada 12 - id 12117091 - status Ended
# Fluminense x Vitória - rodada 12 - id 12117087 - status Ended
# Cuiabá x Internacional - rodada 7 - id 12357205 - status Ended
# Fluminense x Juventude - rodada 7 - id 12357233 - status Ended
# Corinthians x Botafogo - rodada 7 - id 12357219 - status Ended
# Atlético Mineiro x Bahia - rodada 7 - id 12357241 - status Ended
# Criciúma x Palmeiras - rodada 7 - id 12357197 - status Ended
# Vasco x Flamengo - rodada 7 - id 12357227 - status Ended
# Fortaleza x Athletico - rodada 7 - id 12357218 - status Ended
# São Paulo x Cruzeiro - rodada 7 - id 12357263 - status Ended
# Juventude x Atlético Goianiense - rodada 5 - id 12376871 - status Ended
# Cuiabá x Vitória - rodada 2 - id 12376683 - status Ended
# Criciúma x Cuiabá - rodada 6 - id 12376912 - status Ended
# Juventude x Vitória - rodada 8 - id 12359685 - status Ended
# Atlético Goianiense x Corinthians - rodada 8 - id 12357114 - status Ended
# Botafogo x Fluminense - rodada 8 - id 12357122 - status Ended
# Red Bull Bragantino x Atlético Mineiro - rodada 8 - id 12357103 - status Ended
# Cruzeiro x Cuiabá - rodada 8 - id 12357177 - status Ended
# Athletico x Criciúma - rodada 8 - id 12357104 - status Ended
# Internacional x São Paulo - rodada 8 - id 12357186 - status Ended
# Flamengo x Grêmio - rodada 8 - id 12357143 - status Ended
# Bahia x Fortaleza - rodada 8 - id 12357162 - status Ended
# Palmeiras x Vasco - rodada 8 - id 12356168 - status Ended
# Red Bull Bragantino x Juventude - rodada 9 - id 12117060 - status Ended
# Fluminense x Atlético Goianiense - rodada 9 - id 12117057 - status Ended
# Vitória x Internacional - rodada 9 - id 12117056 - status Ended
# Corinthians x São Paulo - rodada 9 - id 12117059 - status Ended
# Athletico x Flamengo - rodada 9 - id 12117061 - status Ended
# Cuiabá x Fortaleza - rodada 9 - id 12117062 - status Ended
# Criciúma x Bahia - rodada 9 - id 12117063 - status Ended
# Vasco x Cruzeiro - rodada 9 - id 12117058 - status Ended
# Grêmio x Botafogo - rodada 9 - id 12117054 - status Ended
# Athletico x Internacional - rodada 3 - id 12117001 - status Ended
# Palmeiras x Flamengo - rodada 3 - id 12116999 - status Ended
# Botafogo x Juventude - rodada 3 - id 12116998 - status Ended
# Atlético Goianiense x São Paulo - rodada 3 - id 12117002 - status Ended
# Vasco x Criciúma - rodada 4 - id 12117008 - status Ended
# Cuiabá x Atlético Mineiro - rodada 4 - id 12117012 - status Ended
# Bahia x Grêmio - rodada 4 - id 12117006 - status Ended
# Flamengo x Botafogo - rodada 4 - id 12117007 - status Ended
# Cruzeiro x Vitória - rodada 4 - id 12117005 - status Ended
# Corinthians x Fluminense - rodada 4 - id 12117009 - status Ended
# Juventude x Athletico - rodada 4 - id 12117013 - status Ended
# Fortaleza x Red Bull Bragantino - rodada 4 - id 12117011 - status Ended
# Internacional x Atlético Goianiense - rodada 4 - id 12117004 - status Ended
# São Paulo x Palmeiras - rodada 4 - id 12117010 - status Ended
# Fluminense x Atlético Mineiro - rodada 5 - id 12117017 - status Ended
# Red Bull Bragantino x Flamengo - rodada 5 - id 12117020 - status Ended
# Corinthians x Fortaleza - rodada 5 - id 12117019 - status Ended
# Athletico x Vasco - rodada 5 - id 12117021 - status Ended
# Vitória x São Paulo - rodada 5 - id 12117016 - status Ended
# Botafogo x Bahia - rodada 5 - id 12117018 - status Ended
# Cuiabá x Palmeiras - rodada 5 - id 12117022 - status Ended
# Flamengo x Corinthians - rodada 6 - id 12117027 - status Ended
# Atlético Goianiense x Cruzeiro - rodada 6 - id 12117032 - status Ended
# Fortaleza x Botafogo - rodada 6 - id 12117031 - status Ended
# Palmeiras x Athletico - rodada 6 - id 12117029 - status Ended
# Bahia x Red Bull Bragantino - rodada 6 - id 12117026 - status Ended
# Vasco x Vitória - rodada 6 - id 12117028 - status Ended
# São Paulo x Fluminense - rodada 6 - id 12117030 - status Ended
# Vitória x Atlético Goianiense - rodada 7 - id 12369730 - status Ended
# Grêmio x Red Bull Bragantino - rodada 7 - id 12357242 - status Ended
# Criciúma x Juventude - rodada 1 - id 12116983 - status Ended
# Internacional x Bahia - rodada 1 - id 12116974 - status Ended
# Fluminense x Red Bull Bragantino - rodada 1 - id 12116977 - status Ended
# São Paulo x Fortaleza - rodada 1 - id 12116980 - status Ended
# Athletico x Cuiabá - rodada 1 - id 12116981 - status Ended
# Vasco x Grêmio - rodada 1 - id 12116978 - status Ended
# Corinthians x Atlético Mineiro - rodada 1 - id 12116979 - status Ended
# Atlético Goianiense x Flamengo - rodada 1 - id 12116982 - status Ended
# Cruzeiro x Botafogo - rodada 1 - id 12116975 - status Ended
# Vitória x Palmeiras - rodada 1 - id 12116976 - status Ended
# Bahia x Fluminense - rodada 2 - id 12116986 - status Ended
# Cuiabá x Vitória - rodada 2 - id 12116992 - status Postponed
# Grêmio x Athletico - rodada 2 - id 12116984 - status Ended
# Red Bull Bragantino x Vasco - rodada 2 - id 12116990 - status Ended
# Atlético Mineiro x Criciúma - rodada 2 - id 12116985 - status Ended
# Fortaleza x Cruzeiro - rodada 2 - id 12116991 - status Ended
# Juventude x Corinthians - rodada 2 - id 12116993 - status Ended
# Palmeiras x Internacional - rodada 2 - id 12116989 - status Ended
# Flamengo x São Paulo - rodada 2 - id 12116987 - status Ended
# Botafogo x Atlético Goianiense - rodada 2 - id 12116988 - status Ended
# Fluminense x Vasco - rodada 3 - id 12116997 - status Ended
# Grêmio x Cuiabá - rodada 3 - id 12116994 - status Ended
# Red Bull Bragantino x Corinthians - rodada 3 - id 12117000 - status Ended
# Atlético Mineiro x Cruzeiro - rodada 3 - id 12116995 - status Ended
# Vitória x Bahia - rodada 3 - id 12116996 - status Ended
# Chaves de 'statistics' encontradas por posição:
# Posição goalkeeper: {'saves', 'expectedAssists', 'totalContest', 'challengeLost', 'aerialWon', 'dispossessed', 'penaltyConceded', 'totalLongBalls', 'punches', 'totalKeeperSweeper', 'wasFouled', 'penaltySave', 'aerialLost', 'errorLeadToAGoal', 'goodHighClaim', 'accurateKeeperSweeper', 'goalsPrevented', 'totalPass', 'accuratePass', 'errorLeadToAShot', 'ratingVersions', 'lastManTackle', 'bigChanceCreated', 'duelWon', 'possessionLostCtrl', 'duelLost', 'fouls', 'keyPass', 'savedShotsFromInsideTheBox', 'goalAssist', 'touches', 'rating', 'accurateLongBalls', 'expectedGoals', 'interceptionWon', 'totalClearance', 'wonContest', 'minutesPlayed', 'totalTackle'}
# Posição defender: {'expectedAssists', 'totalContest', 'hitWoodwork', 'dispossessed', 'penaltyConceded', 'totalOffside', 'outfielderBlock', 'clearanceOffLine', 'aerialLost', 'errorLeadToAGoal', 'penaltyWon', 'accuratePass', 'accurateCross', 'ratingVersions', 'bigChanceCreated', 'duelLost', 'duelWon', 'fouls', 'bigChanceMissed', 'keyPass', 'expectedGoals', 'totalClearance', 'minutesPlayed', 'totalTackle', 'blockedScoringAttempt', 'challengeLost', 'aerialWon', 'totalLongBalls', 'wasFouled', 'totalPass', 'errorLeadToAShot', 'lastManTackle', 'possessionLostCtrl', 'totalCross', 'goalAssist', 'ownGoals', 'touches', 'rating', 'accurateLongBalls', 'interceptionWon', 'onTargetScoringAttempt', 'goals', 'wonContest', 'shotOffTarget'}
# Posição midfield: {'expectedAssists', 'totalContest', 'hitWoodwork', 'dispossessed', 'totalOffside', 'penaltyConceded', 'outfielderBlock', 'clearanceOffLine', 'aerialLost', 'errorLeadToAGoal', 'penaltyWon', 'accuratePass', 'accurateCross', 'ratingVersions', 'bigChanceCreated', 'duelLost', 'duelWon', 'fouls', 'bigChanceMissed', 'keyPass', 'expectedGoals', 'totalClearance', 'minutesPlayed', 'totalTackle', 'blockedScoringAttempt', 'challengeLost', 'aerialWon', 'totalLongBalls', 'wasFouled', 'totalPass', 'errorLeadToAShot', 'lastManTackle', 'possessionLostCtrl', 'totalCross', 'goalAssist', 'penaltyMiss', 'touches', 'ownGoals', 'rating', 'accurateLongBalls', 'interceptionWon', 'onTargetScoringAttempt', 'goals', 'wonContest', 'shotOffTarget'}
# Posição forward: {'expectedAssists', 'totalContest', 'hitWoodwork', 'dispossessed', 'totalOffside', 'penaltyConceded', 'outfielderBlock', 'clearanceOffLine', 'aerialLost', 'errorLeadToAGoal', 'penaltyWon', 'accuratePass', 'accurateCross', 'ratingVersions', 'bigChanceCreated', 'duelLost', 'duelWon', 'fouls', 'bigChanceMissed', 'keyPass', 'expectedGoals', 'totalClearance', 'minutesPlayed', 'totalTackle', 'blockedScoringAttempt', 'challengeLost', 'aerialWon', 'totalLongBalls', 'wasFouled', 'totalPass', 'errorLeadToAShot', 'possessionLostCtrl', 'totalCross', 'goalAssist', 'penaltyMiss', 'touches', 'ownGoals', 'rating', 'accurateLongBalls', 'interceptionWon', 'onTargetScoringAttempt', 'goals', 'wonContest', 'shotOffTarget'}

# %%
import os
import requests
import json
from pprint import pprint
from collections import defaultdict
import pandas as pd

# Mapeamento de posições conforme a função generate_player_document
position_map = {
    'G': 'goalkeeper',
    'D': 'defender',
    'M': 'midfield',
    'F': 'forward'
}

# Função para classificar o rating em uma nova chave 'ratingLabel'
def classify_rating(rating):
    if 3 <= rating < 6:
        return 'terrible'
    elif 6 <= rating < 6.5:
        return 'bad'
    elif 6.5 <= rating < 7:
        return 'average'
    elif 7 <= rating < 8:
        return 'good'
    elif 8 <= rating < 9:
        return 'great'
    elif rating >= 9:
        return 'excellent'
    return 'unknown'

# Conjunto de estatísticas relevantes por posição
position_required_stats = {
    'forward': ['goals', 'goalAssist', 'onTargetScoringAttempt'],
    'midfield': ['accuratePass', 'keyPass', 'goalAssist'],
    'defender': ['totalTackle', 'totalClearance', 'interceptionWon'],
    'goalkeeper': ['saves', 'goalsPrevented', 'goodHighClaim']
}

# Função para processar os dados e adicionar a classificação de rating
def process_player_data(players, event_description):
    processed_data = []
    statistics_keys = [
        'goals', 'goalAssist', 'onTargetScoringAttempt', 'accuratePass',
        'keyPass', 'totalTackle', 'totalClearance', 'interceptionWon',
        'saves', 'goalsPrevented', 'goodHighClaim', 'rating'
    ]

    for player in players:
        position = position_map.get(player.get('position'), 'Unknown')
        if position == 'Unknown':
            continue

        statistics = player.get('statistics', {})
        rating = statistics.get('rating', 0)

        # Verificar se todas as estatísticas requeridas para a posição estão presentes
        required_stats = position_required_stats.get(position, [])
        if not all(stat in statistics and statistics[stat] != 0 for stat in required_stats):
            continue

        # Classificar o rating
        rating_label = classify_rating(rating)
        player['ratingLabel'] = rating_label

        # Montar features com base nas estatísticas chave
        features = {
            'player_name': player['player']['name'],
            'position': position,
            'rating': rating,
            'ratingLabel': rating_label,
            'event_id': player.get('event_id'),  # Adicionar o event_id para referência
            'event_description': event_description  # Adicionar descrição do evento
        }

        for key in statistics_keys:
            features[key] = statistics.get(key, 0)

        processed_data.append(features)

    return processed_data

# Função principal para processar eventos e preparar os dados para fine-tuning
def process_events_for_fine_tuning(qtd_eventos, all_events):
    all_processed_data = []

    for event in range(qtd_eventos):
        event_id = all_events[event]['id']
        data_games = get_event_data(event_id)
        status = data_games['event']['status']['description']

        if status == 'Ended':
            home_team = data_games['event']['homeTeam']['name']
            away_team = data_games['event']['awayTeam']['name']
            event_description = f"{home_team} vs {away_team}"  # Descrição do evento

            # Obter lineups do evento
            lineups = get_event_lineups(event_id)

            # Processar jogadores do time da casa
            home_players = lineups['home']['players']
            # Adiciona o event_id aos jogadores para facilitar o cálculo de médias
            for player in home_players:
                player['event_id'] = event_id
            all_processed_data.extend(process_player_data(home_players, event_description))

            # Processar jogadores do time visitante
            away_players = lineups['away']['players']
            # Adiciona o event_id aos jogadores para facilitar o cálculo de médias
            for player in away_players:
                player['event_id'] = event_id
            all_processed_data.extend(process_player_data(away_players, event_description))

    return all_processed_data

# Inclua a lógica atual de obtenção de eventos
url_base = "https://www.sofascore.com/api/v1/unique-tournament/325/season/58766/events/last/"
page_number = 0
all_events = []

while True:
    url = url_base + str(page_number)
    response = requests.get(url)

    if response.status_code == 404:
        break

    if response.status_code == 200:
        data = json.loads(response.content)

        if 'events' in data:
            all_events.extend(data['events'])
        else:
            print(f"Aviso: Chave 'events' não encontrada na página {page_number}.")

        page_number += 1
    else:
        print(f"Erro na requisição da página {page_number}: Código de status {response.status_code}")
        break

print(f"Total de eventos coletados: {len(all_events)}")

# Executa o processamento dos eventos para preparar os dados
qtd_eventos = len(all_events)  # Supondo que você tenha o total de eventos
processed_data = process_events_for_fine_tuning(qtd_eventos, all_events)

# Convertendo os dados para um DataFrame do Pandas para fácil manipulação
df = pd.DataFrame(processed_data)

# Calculando as médias das estatísticas para jogadores da mesma posição dentro do mesmo evento
statistics_keys = [
    'goals', 'goalAssist', 'onTargetScoringAttempt', 'accuratePass',
    'keyPass', 'totalTackle', 'totalClearance', 'interceptionWon',
    'saves', 'goalsPrevented', 'goodHighClaim', 'rating'
]

# Calcula as médias por evento e posição
event_position_means = df.groupby(['event_id', 'position'])[statistics_keys].mean().reset_index()

# Renomeia as colunas para indicar que são médias por evento e posição
event_position_means.columns = ['event_id', 'position'] + [f'avg_{col}' for col in statistics_keys]

# Junta as médias calculadas de volta ao DataFrame principal
df = df.merge(event_position_means, on=['event_id', 'position'], how='left')

# Salva o DataFrame como CSV para uso posterior no fine-tuning
df.to_csv('processed_player_data.csv', index=False)
print("Dados processados e salvos com sucesso para fine-tuning.")
print("df.shape:", df.shape)

df.head()
# Out:
# Total de eventos coletados: 295
# Dados processados e salvos com sucesso para fine-tuning.
# df.shape: (1557, 29)
#          player_name  position  rating ratingLabel  event_id  \
# 0     Emanuel Brítez  defender     7.3        good  12117241
# 1  Benjamin Kuscevic  defender     7.0        good  12117241
# 2      Tomás Cardona  defender     7.4        good  12117241
# 3       Eros Mancuso  defender     6.4         bad  12117241
# 4         Zé Welison  midfield     6.3         bad  12117241
#
#     event_description  goals  goalAssist  onTargetScoringAttempt  \
# 0  Fortaleza vs Bahia      0           1                       0
# 1  Fortaleza vs Bahia      0           0                       0
# 2  Fortaleza vs Bahia      0           0                       0
# 3  Fortaleza vs Bahia      0           0                       0
# 4  Fortaleza vs Bahia      0           1                       0
#
#    accuratePass  ...  avg_onTargetScoringAttempt  avg_accuratePass  \
# 0            24  ...                         0.0         48.142857
# 1            28  ...                         0.0         48.142857
# 2            42  ...                         0.0         48.142857
# 3            30  ...                         0.0         48.142857
# 4            32  ...                         0.0         29.333333
#
#    avg_keyPass  avg_totalTackle  avg_totalClearance  avg_interceptionWon  \
# 0     0.857143         2.857143            3.000000             1.857143
# 1     0.857143         2.857143            3.000000             1.857143
# 2     0.857143         2.857143            3.000000             1.857143
# 3     0.857143         2.857143            3.000000             1.857143
# 4     1.333333         1.666667            0.333333             0.333333
#
#    avg_saves  avg_goalsPrevented  avg_goodHighClaim  avg_rating
# 0        0.0                 0.0                0.0    6.885714
# 1        0.0                 0.0                0.0    6.885714
# 2        0.0                 0.0                0.0    6.885714
# 3        0.0                 0.0                0.0    6.885714
# 4        0.0                 0.0                0.0    6.766667
#
# [5 rows x 29 columns]

# %%
df.tail()
# Out:
#          player_name  position  rating ratingLabel  event_id  \
# 1552   Lucas Esteves  defender     7.5        good  12116996
# 1553     Matheuzinho   forward     8.3       great  12116996
# 1554  Santiago Arias  defender     6.8     average  12116996
# 1555    Luciano Juba  defender     6.8     average  12116996
# 1556            Biel   forward     8.3       great  12116996
#
#      event_description  goals  goalAssist  onTargetScoringAttempt  \
# 1552  Vitória vs Bahia      0           0                       1
# 1553  Vitória vs Bahia      1           1                       3
# 1554  Vitória vs Bahia      0           0                       0
# 1555  Vitória vs Bahia      0           0                       0
# 1556  Vitória vs Bahia      1           1                       1
#
#       accuratePass  ...  avg_onTargetScoringAttempt  avg_accuratePass  \
# 1552            39  ...                         0.5              45.5
# 1553            21  ...                         2.0              17.0
# 1554            37  ...                         0.5              45.5
# 1555            55  ...                         0.5              45.5
# 1556            13  ...                         2.0              17.0
#
#       avg_keyPass  avg_totalTackle  avg_totalClearance  avg_interceptionWon  \
# 1552          1.5              2.5                4.75                  1.0
# 1553          1.5              0.5                0.00                  1.5
# 1554          1.5              2.5                4.75                  1.0
# 1555          1.5              2.5                4.75                  1.0
# 1556          1.5              0.5                0.00                  1.5
#
#       avg_saves  avg_goalsPrevented  avg_goodHighClaim  avg_rating
# 1552        0.0                 0.0                0.0       7.225
# 1553        0.0                 0.0                0.0       8.300
# 1554        0.0                 0.0                0.0       7.225
# 1555        0.0                 0.0                0.0       7.225
# 1556        0.0                 0.0                0.0       8.300
#
# [5 rows x 29 columns]

# %%
df.loc[0]
# Out:
# player_name                       Emanuel Brítez
# position                                defender
# rating                                       7.3
# ratingLabel                                 good
# event_id                                12117241
# event_description             Fortaleza vs Bahia
# goals                                          0
# goalAssist                                     1
# onTargetScoringAttempt                         0
# accuratePass                                  24
# keyPass                                        2
# totalTackle                                    1
# totalClearance                                 1
# interceptionWon                                3
# saves                                          0
# goalsPrevented                               0.0
# goodHighClaim                                  0
# avg_goals                                    0.0
# avg_goalAssist                          0.142857
# avg_onTargetScoringAttempt                   0.0
# avg_accuratePass                       48.142857
# avg_keyPass                             0.857143
# avg_totalTackle                         2.857143
# avg_totalClearance                           3.0
# avg_interceptionWon                     1.857143
# avg_saves                                    0.0
# avg_goalsPrevented                           0.0
# avg_goodHighClaim                            0.0
# avg_rating                              6.885714
# Name: 0, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1557 entries, 0 to 1556
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   player_name                 1557 non-null   object
#  1   position                    1557 non-null   object
#  2   rating                      1557 non-null   float64
#  3   ratingLabel                 1557 non-null   object
#  4   event_id                    1557 non-null   int64
#  5   event_description           1557 non-null   object
#  6   goals                       1557 non-null   int64
#  7   goalAssist                  1557 non-null   int64
#  8   onTargetScoringAttempt      1557 non-null   int64
#  9   accuratePass                1557 non-null   int64
#  10  keyPass                     1557 non-null   int64
#  11  totalTackle                 1557 non-null   int64
#  12  totalClearance              1557 non-null   int64
#  13  interceptionWon             1557 non-null   int64
#  14  saves                       1557 non-null   int64
#  15  goalsPrevented              1557 non-null   float64
#  16  goodHighClaim               1557 non-null   int64
#  17  avg_goals                   1557 non-null   float64
#  18  avg_goalAssist              1557 non-null   float64
#  19  avg_onTargetScoringAttempt  1557 non-null   float64
#  20  avg_accuratePass            1557 non-null   float64
#  21  avg_keyPass                 1557 non-null   float64
#  22  avg_totalTackle             1557 non-null   float64
#  23  avg_totalClearance          1557 non-null   float64
#  24  avg_interceptionWon         1557 non-null   float64
#  25  avg_saves                   1557 non-null   float64
#  26  avg_goalsPrevented          1557 non-null   float64
#  27  avg_goodHighClaim           1557 non-null   float64
#  28  avg_rating                  1557 non-null   float64
# dtypes: float64(14), int64(11), object(4)
# memory usage: 352.9+ KB

# %%
def create_training_data(df):
    """
    Adiciona colunas 'x' e 'y' ao DataFrame original para fine-tuning do Llama 2,
    formatando as estatísticas com uma casa decimal.

    Args:
        df: DataFrame original com os dados dos jogadores.

    Returns:
        DataFrame: DataFrame original com as colunas 'x' (texto de entrada) e 'y' (rótulo de avaliação) adicionadas.
    """

    for _, row in df.iterrows():
        player_stats = row.to_dict()

        # Formata as estatísticas com uma casa decimal
        for key in player_stats:
            if isinstance(player_stats[key], float):
                player_stats[key] = f"{player_stats[key]:.1f}"

        base_performance_response = f"In the match between {player_stats.get('event_description')}, the player {player_stats.get('player_name')}, playing as a {player_stats.get('position')}"

        if player_stats.get('position') == 'forward':
            base_performance_response += f" scored {player_stats.get('goals')} goals, provided {player_stats.get('goalAssist')} assists, and had {player_stats.get('onTargetScoringAttempt')} shots on target."
        elif player_stats.get('position') == 'midfield':
            base_performance_response += f" had {player_stats.get('accuratePass')} accurate passes, created {player_stats.get('keyPass')} key chances, and provided {player_stats.get('goalAssist')} assists."
        elif player_stats.get('position') == 'defender':
            base_performance_response += f" made {player_stats.get('totalTackle')} tackles, {player_stats.get('totalClearance')} clearances, and {player_stats.get('interceptionWon')} interceptions."
        elif player_stats.get('position') == 'goalkeeper':
            base_performance_response += f" made {player_stats.get('saves')} saves, prevented {player_stats.get('goalsPrevented')} goals, and made {player_stats.get('goodHighClaim')} high claims."

        base_performance_response += " The average for players in this position was "

        if player_stats.get('position') == 'forward':
            base_performance_response += f"{player_stats.get('avg_goals')} goals, {player_stats.get('avg_goalAssist')} assists, and {player_stats.get('avg_onTargetScoringAttempt')} shots on target."
        elif player_stats.get('position') == 'midfield':
            base_performance_response += f"{player_stats.get('avg_accuratePass')} accurate passes, {player_stats.get('avg_keyPass')} key chances, and {player_stats.get('avg_goalAssist')} assists."
        elif player_stats.get('position') == 'defender':
            base_performance_response += f"{player_stats.get('avg_totalTackle')} tackles, {player_stats.get('avg_totalClearance')} clearances, and {player_stats.get('avg_interceptionWon')} interceptions."
        elif player_stats.get('position') == 'goalkeeper':
            base_performance_response += f"{player_stats.get('avg_saves')} saves, {player_stats.get('avg_goalsPrevented')} prevented goals, and {player_stats.get('avg_goodHighClaim')} high claims."

        base_performance_response += " Taking this into account, how was his performance?"

        df.loc[_, 'x'] = base_performance_response
        df.loc[_, 'y'] = f"His performance was " + player_stats.get('ratingLabel')

    return df

df = create_training_data(df)
df.head()
# Out:
#          player_name  position  rating ratingLabel  event_id  \
# 0     Emanuel Brítez  defender     7.3        good  12117241
# 1  Benjamin Kuscevic  defender     7.0        good  12117241
# 2      Tomás Cardona  defender     7.4        good  12117241
# 3       Eros Mancuso  defender     6.4         bad  12117241
# 4         Zé Welison  midfield     6.3         bad  12117241
#
#     event_description  goals  goalAssist  onTargetScoringAttempt  \
# 0  Fortaleza vs Bahia      0           1                       0
# 1  Fortaleza vs Bahia      0           0                       0
# 2  Fortaleza vs Bahia      0           0                       0
# 3  Fortaleza vs Bahia      0           0                       0
# 4  Fortaleza vs Bahia      0           1                       0
#
#    accuratePass  ...  avg_keyPass  avg_totalTackle  avg_totalClearance  \
# 0            24  ...     0.857143         2.857143            3.000000
# 1            28  ...     0.857143         2.857143            3.000000
# 2            42  ...     0.857143         2.857143            3.000000
# 3            30  ...     0.857143         2.857143            3.000000
# 4            32  ...     1.333333         1.666667            0.333333
#
#    avg_interceptionWon  avg_saves  avg_goalsPrevented  avg_goodHighClaim  \
# 0             1.857143        0.0                 0.0                0.0
# 1             1.857143        0.0                 0.0                0.0
# 2             1.857143        0.0                 0.0                0.0
# 3             1.857143        0.0                 0.0                0.0
# 4             0.333333        0.0                 0.0                0.0
#
#    avg_rating                                                  x  \
# 0    6.885714  In the match between Fortaleza vs Bahia, the p...
# 1    6.885714  In the match between Fortaleza vs Bahia, the p...
# 2    6.885714  In the match between Fortaleza vs Bahia, the p...
# 3    6.885714  In the match between Fortaleza vs Bahia, the p...
# 4    6.766667  In the match between Fortaleza vs Bahia, the p...
#
#                           y
# 0  His performance was good
# 1  His performance was good
# 2  His performance was good
# 3   His performance was bad
# 4   His performance was bad
#
# [5 rows x 31 columns]

# %%
df.loc[0, 'x']
# Out:
# 'In the match between Fortaleza vs Bahia, the player Emanuel Brítez, playing as a defender made 1 tackles, 1 clearances, and 3 interceptions. The average for players in this position was 2.9 tackles, 3.0 clearances, and 1.9 interceptions. Taking this into account, how was his performance?'

# %%
df_train = df[['x', 'y']]
df_train.head()
# Out:
#                                                    x                         y
# 0  In the match between Fortaleza vs Bahia, the p...  His performance was good
# 1  In the match between Fortaleza vs Bahia, the p...  His performance was good
# 2  In the match between Fortaleza vs Bahia, the p...  His performance was good
# 3  In the match between Fortaleza vs Bahia, the p...   His performance was bad
# 4  In the match between Fortaleza vs Bahia, the p...   His performance was bad

# %%
df_train = df_train.rename(columns={'x': 'Instructions', 'y': 'Responses'})
df_train.head()
# Out:
#                                         Instructions                 Responses
# 0  In the match between Fortaleza vs Bahia, the p...  His performance was good
# 1  In the match between Fortaleza vs Bahia, the p...  His performance was good
# 2  In the match between Fortaleza vs Bahia, the p...  His performance was good
# 3  In the match between Fortaleza vs Bahia, the p...   His performance was bad
# 4  In the match between Fortaleza vs Bahia, the p...   His performance was bad

# %%
df_train.to_csv('player_performance_analysis_dataset.csv', sep=';', index=False)
